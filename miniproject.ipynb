# %%
from keras.preprocessing.image import img_to_array
import utils 
from tensorflow.keras.models import load_model
import numpy as np
import cv2 
from matplotlib import pyplot as plt 
import time 
import os 
from playsound import playsound

# %%
face_classifier= cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))

# %%
emotion_model=load_model("model.h5")

# %%
EMOTIONS_LIST = ["Angry", "Disgust", "Fear", "Happy", "Neutral","Sad","Surprised"]

# %%
gray = cv2.imread('virat.jpg')

# %%
plt.figure(figsize=(12,8))
plt.imshow(gray,cmap='plasma')

# Detect faces
faces = face_classifier.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=5,flags=cv2.CASCADE_SCALE_IMAGE)
for (x, y, w, h) in faces: 
    cv2.rectangle(gray, (x, y), (x+w, y+h), (25, 255, 255), 3)    
plt.figure(figsize=(12,8))
plt.imshow(gray, cmap='plasma')
plt.show()
fc = gray[y:y+h, x:x+w]
roi = cv2.resize(fc, (48, 48))
plt.figure(figsize=(12,8))
plt.imshow(roi, cmap='plasma')
plt.show()
def predict_emotion(img):
    preds = emotion_model.predict(img)
    return EMOTIONS_LIST[np.argmax(preds)]
pred = predict_emotion(roi[np.newaxis, :, :, np.newaxis])
print(pred)
# Out:
# Happy

# %%
if pred == 'Angry':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\anger\\anger_Rakshasudu ! Mass Bgm ! Surya ! Telugu ! 2019.mp3")
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\anger\\anger_Joker Angry Mood ! Background Music.mp3")
if pred == 'Happy':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\happy\\happy_Oh Makhna Ve Makhna - Drive.mp3")
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\happy\\happy_Cheap Thrills.mp3")    
if pred == 'Disgust':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\disgust\\disgust_Disgust .io.mp3")
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\disgust\\disgust_Broken_Hopeless_Ringtone_(by Fringster.com).mp3")
if pred == 'Sad':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\sad\\Sad.Co.mp3")
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\sad\\sad_BGM - Agar tum sath ho.mp3")
    
if pred == 'Neutral':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\neutral\\neutral_Pehli Nazar Mein.mp3")
if pred == 'Fear':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\fear\\fear_Spyder - Psycho Villian Bgm.mp3")
if pred == 'Surprised':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\surprise\\surpise_Dil Chori.mp3")

# %% [markdown]
# ### print(roi[np.newaxis, :, :, np.newaxis])

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
now = time.time()
future = now+15


def predict_emotion(img):
        preds = emotion_model.predict(img)
        return EMOTIONS_LIST[np.argmax(preds)]
    
    
video_capture = cv2.VideoCapture(0)


while True:
    
    # Capture frame-by-frame
    ret, frame = video_capture.read()
    frame = cv2.flip(frame, 1, 0)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 30),
        flags=cv2.CASCADE_SCALE_IMAGE
        )
    
    
    for (x, y, w, h) in faces:
        #if w > 250 :
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 3)
        roi_gray = gray[y:y+h, x:x+w]
            #roi_color = frame[y:y+h, x:x+w]
        roi = cv2.resize(roi_gray, (48, 48))
        pred = predict_emotion(roi[np.newaxis, :, :, np.newaxis])
        cv2.putText(frame, pred, (x+(w//3), y-5), font, 2, (0, 0, 255), 2)
        
    #print(pred) 
    #print(type(pred))
    cv2.imshow('Video', frame)
    key = cv2.waitKey(30)& 0xff
    #print(time.time())
    #print(future)
    if time.time() > future:##after 20second music will play
        try:
            #video_capture.release()
            cv2.destroyAllWindows()
            print(pred)
           
              
            break
        
        except :
            print('Please stay focus in Camera frame atleast 15 seconds & run again this program:)')
            break
    if key == 27:
        break
video_capture.release()

# %%
if pred == 'Angry':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\anger\\anger_Rakshasudu ! Mass Bgm ! Surya ! Telugu ! 2019.mp3")
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\anger\\anger_Joker Angry Mood ! Background Music.mp3")
if pred == 'Happy':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\happy\\happy_Oh Makhna Ve Makhna - Drive.mp3")
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\happy\\happy_Cheap Thrills.mp3")    
if pred == 'Disgust':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\disgust\\disgust_Disgust .io.mp3")
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\disgust\\disgust_Broken_Hopeless_Ringtone_(by Fringster.com).mp3")
if pred == 'Sad':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\sad\\Sad.Co.mp3")
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\sad\\sad_BGM - Agar tum sath ho.mp3")
    
if pred == 'Neutral':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\neutral\\neutral_Pehli Nazar Mein.mp3")
if pred == 'Fear':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\fear\\fear_Spyder - Psycho Villian Bgm.mp3")
if pred == 'Surprised':
    playsound("C:\\Users\\lavan\\OneDrive\\Desktop\\miniproject\\surprise\\surpise_Dil Chori.mp3")
